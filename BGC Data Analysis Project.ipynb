# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# # 1. Read input file and convert to DataFrame

# %%
# Load corp_pfd.dif file
with open("corp_pfd.dif", "r") as file:
    lines = file.readlines()

# %%
# Extract column names from corp_pfd.dif (excluding those that start with #)
start_index = lines.index("START-OF-FIELDS\n") + 1
end_index = lines.index("END-OF-FIELDS\n")
corp_pfd_columns = [line.strip() for line in lines[start_index:end_index] if line.strip() and not line.startswith("#")]

# %%
# Read corp_pfd.dif
corp_pfd_data = []
data_started = False
for line in lines:
    line = line.strip()
    if line == "START-OF-DATA":
        data_started = True
        continue
    elif line == "END-OF-DATA":
        break
    if data_started:
        # Split the line into fields and remove trailing spaces from each field
        fields = [field.rstrip() for field in line.split("|")]
        # Remove the last blank field 
        fields = fields[:-1]
        record = {}
        for col in corp_pfd_columns:
            record[col] = fields[corp_pfd_columns.index(col)]
        corp_pfd_data.append(record)

# %%
# Create DataFrame from the extracted data
corp_pfd_df = pd.DataFrame(corp_pfd_data)

# %%
corp_pfd_df
# Out:
#      TICKER_YELLOW_KEY ST1 REF1  TICKER        CPN  MATURITY SERIES  \
# 0       AS3629704 Corp  -1  210    MTRC   2.560000  20210502   EMTN
# 1       AS3764410 Corp  -1  210  CILBAR  33.921460  20210502      I
# 2       ZS2774298 Corp  -1  210  REDPRO   9.875000  20210502
# 3       4590568X8 Corp   0  210    IBRD       N.A.  20831201
# 4       AF1220108 Corp   0  210  POSADA   7.875000  20220630   144A
# ...                ...  ..  ...     ...        ...       ...    ...
# 2891    ZS8358328 Corp   0  210  USJACU   9.875000  20231109   144A
# 2892    ZS8402340 Corp   0  210  USJACU   9.875000  20231109   REGS
# 2893    ZS8705577 Corp   0  210   LTMCI   3.600000  20290415      E
# 2894    ZS8952088 Corp   0  210  SECUCL   4.400000  20240415      H
# 2895    ZS9312746 Corp   0  210   GMFIN   4.830000  20210528     19
#
#                          NAME        SHORT_NAME  ISSUER_INDUSTRY  ...  \
# 0             MTR CORP CI LTD   MTR CORP CI LTD  SPECIAL PURPOSE  ...
# 1                CILBRAKE SRL      CILBRAKE SRL       INDUSTRIAL  ...
# 2      REDCO PROPERTIES GROUP  REDCO PROPERTIES        FINANCIAL  ...
# 3     INTL BK RECON & DEVELOP  INT BK RECON&DEV   SUPRA-NATIONAL  ...
# 4        GRUPO POSADAS SAB CV     GRUPO POSADAS       INDUSTRIAL  ...
# ...                       ...               ...              ...  ...
# 2891   USJ ACUCAR E ALCOOL SA   USJ ACUCAR E AL       INDUSTRIAL  ...
# 2892   USJ ACUCAR E ALCOOL SA   USJ ACUCAR E AL       INDUSTRIAL  ...
# 2893  LATAM AIRLINES GROUP SA         LATAM AIR       INDUSTRIAL  ...
# 2894    FACTORING SECURITY SA  FACTORING SECURI        FINANCIAL  ...
# 2895   GM FINANCIAL DE MEXICO  GM FIN DE MEXICO        FINANCIAL  ...
#
#      INDUSTRY_GROUP_NUM INDUSTRY_SECTOR_NUM ISSUERS_STOCK INFLATION_LAG  \
# 0                 20091               10011                        N.A.
# 1                 20022               10004                        N.A.
# 2                 20058               10008                        N.A.
# 3                 20073               10010                        N.A.
# 4                 20029               10004                        N.A.
# ...                 ...                 ...           ...           ...
# 2891              20040               10005                        N.A.
# 2892              20040               10005                        N.A.
# 2893              20018               10004                           1
# 2894              20054               10008                        N.A.
# 2895              20054               10008                        N.A.
#
#      MAKE_WHOLE_CALL_SPREAD              ISSUER_BULK  \
# 0                      N.A.          MTR CORP CI LTD
# 1                      N.A.             CILBRAKE SRL
# 2                      N.A.   REDCO PROPERTIES GROUP
# 3                      N.A.  INTL BK RECON & DEVELOP
# 4                    50.000     GRUPO POSADAS SAB CV
# ...                     ...                      ...
# 2891                   N.A.   USJ ACUCAR E ALCOOL SA
# 2892                   N.A.   USJ ACUCAR E ALCOOL SA
# 2893                   N.A.  LATAM AIRLINES GROUP SA
# 2894                   N.A.    FACTORING SECURITY SA
# 2895                   N.A.   GM FINANCIAL DE MEXICO
#
#                ID_BB_SEC_NUM_DES FEED_SOURCE ID_BB_GLOBAL_COMPANY  \
# 0        MTRC 2.56 05/02/21 EMTN         BGN         BBG001GBHFS3
# 1            CILBAR F 05/02/21 I         BGN         BBG00KRC8B42
# 2          REDPRO 9.875 05/02/21         BGN         BBG005WQH7K9
# 3               IBRD V0 12/01/83         BGN         BBG001FHC3T2
# 4     POSADA 7.875 06/30/22 144A         BGN         BBG001FGB048
# ...                          ...         ...                  ...
# 2891  USJACU 9.875 11/09/23 144A         BGN         BBG002R2PND9
# 2892  USJACU 9.875 11/09/23 REGS         BGN         BBG002R2PND9
# 2893        LTMCI 3.6 04/15/29 E         BGN         BBG001FGQ4Q0
# 2894       SECUCL 4.4 04/15/24 H         BGN         BBG001H1W8B1
# 2895         GMFIN F 05/28/21 19         BGN         BBG001GG14X8
#
#                               ID_BB_GLOBAL_COMPANY_NAME
# 0                                       MTR Corp CI Ltd
# 1                                          Cilbrake SRL
# 2                            Redco Properties Group Ltd
# 3     International Bank for Reconstruction & Develo...
# 4                               Grupo Posadas SAB de CV
# ...                                                 ...
# 2891                            USJ-Acucar e Alcool S/A
# 2892                            USJ-Acucar e Alcool S/A
# 2893                            Latam Airlines Group SA
# 2894                              Factoring Security SA
# 2895           GM Financial de Mexico SA de CV SOFOM ER
#
# [2896 rows x 213 columns]

# %%
#check to make sure the # of name fields and data fields match up
print(len(corp_pfd_columns))
print(len(fields))
# Out:
# 213
# 213

# %% [markdown]
# # 2. Limit columns in DataFrame to only those found in reference_fields.csv

# %%
# Read reference_fields.csv
reference_fields_df = pd.read_csv("reference_fileds.csv")

# %%
reference_fields_df
# Out:
#                         field  id_field
# 0    3MTH_IMPVOL_100.0%MNY_DF         0
# 1     3MTH_IMPVOL_90.0%MNY_DF         0
# 2    ACCRUED_INTEREST_TO_DATE         0
# 3              ADR_SH_PER_ADR         0
# 4              ALTMAN_Z_SCORE         0
# ..                        ...       ...
# 265                WRT_SH_PER         0
# 266              YAS_BOND_YLD         0
# 267               YAS_MOD_DUR         0
# 268            YAS_YLD_SPREAD         0
# 269          YRS_TO_MTY_ISSUE         0
#
# [270 rows x 2 columns]

# %%
# Get the column names from reference_fields.csv
reference_columns = reference_fields_df["field"].tolist()

# %%
reference_columns
# Out:
# ['3MTH_IMPVOL_100.0%MNY_DF',
#  '3MTH_IMPVOL_90.0%MNY_DF',
#  'ACCRUED_INTEREST_TO_DATE',
#  'ADR_SH_PER_ADR',
#  'ALTMAN_Z_SCORE',
#  'AMT_OUTSTANDING',
#  'ARM_INITIAL_FIXED_PERIOD_MONTHS',
#  'BB_COMPOSITE',
#  'BDVD_NEXT_EST_EX_DT',
#  'BETA_RAW_OVERRIDABLE',
#  'BLP_SPRD_TO_BENCH_LAST',
#  'BLP_SWAP_CURVE_NAME',
#  'BOND_TO_EQY_TICKER',
#  'BS_TOT_ASSET',
#  'CALC_TYP_DES',
#  'CALL_IMP_VOL_30D',
#  'CASH_SETTLED',
#  'CAST_PARENT_NAME',
#  'CDS_CASH_SETTLED_AMOUNT',
#  'CDS_FLAT_SPREAD',
#  'CDS_QUOTED_PRICE',
#  'CDS_RED_PAIR_CODE',
#  'CDS_REPL',
#  'CDS_RR',
#  'CNTRY_OF_DOMICILE',
#  'CNTRY_OF_INCORPORATION',
#  'CNTRY_OF_RISK',
#  'COLLAT_TYP',
#  'CONTINGENT_CNVS_END_DT',
#  'CONTINGENT_CONVERSION',
#  'CONTRACT_VALUE',
#  'CONVERTIBLE',
#  'CORP_BOND_INDICATOR',
#  'COUNT_INDEX_MEMBERS',
#  'COUNTRY',
#  'COUNTRY_FULL_NAME',
#  'COUNTRY_ISO',
#  'COUNTRY_RISK_ISO_CODE',
#  'COUPON',
#  'CPN',
#  'CPN_TYP',
#  'CRNCY',
#  'CRNCY_ADJ_MKT_CAP',
#  'CRNCY_ADJ_PX_LAST',
#  'CUR_CPN',
#  'CUR_MKT_CAP',
#  'CURVE_ID',
#  'CURVE_ISSUER',
#  'CURVE_NAME',
#  'CURVE_SUBTYPE',
#  'CURVE_TERMS',
#  'CURVE_TYPE',
#  'CV_CNVS_RATIO',
#  'CV_COMMON_TICKER',
#  'CV_COMMON_TICKER_EXCH',
#  'CV_MODEL_PARITY',
#  'CV_PARITY',
#  'CV_STOCK_PX',
#  'DAY_CNT_DES',
#  'DAYS_TO_MTY',
#  'DDIS_CURRENCY',
#  'DEFAULTED',
#  'DS086',
#  'DS156',
#  'DS213',
#  'DS530',
#  'DS674',
#  'DSB_REFERENCE_RATE',
#  'DUR_ADJ_OAS_MID',
#  'DVD_EX_DT',
#  'DX615',
#  'EQY_BETA',
#  'EQY_FLOAT',
#  'EQY_FUND_CRNCY',
#  'EQY_SH_OUT',
#  'EQY_SH_OUT_REAL',
#  'ETF_UNDL_INDEX_TICKER',
#  'EXCH_CODE',
#  'FIRST_SETTLE_DT',
#  'FLT_SPREAD',
#  'FUND_ASSET_CLASS_FOCUS',
#  'FUND_GEO_FOCUS',
#  'FUND_LEVERAGE_AMOUNT',
#  'FUND_NET_ASSET_VAL',
#  'FUND_OBJECTIVE_LONG',
#  'FUNDAMENTALS_TICKER',
#  'FUT_CONT_SIZE',
#  'FUT_CTD_CUSIP',
#  'FUT_EXCH_NAME_LONG',
#  'FUT_VAL_PT',
#  'FUTURES_CATEGORY',
#  'GICS_INDUSTRY_GROUP_NAME',
#  'GICS_INDUSTRY_NAME',
#  'GICS_SECTOR_NAME',
#  'GICS_SUB_INDUSTRY_NAME',
#  'HEALTH_GRADE',
#  'HIGH_52WEEK',
#  'ICB_INDUSTRY_NAME',
#  'ICB_SECTOR_NAME',
#  'ICB_SUBSECTOR_NAME',
#  'ICB_SUPERSECTOR_NAME',
#  'ID_BB_GLOBAL',
#  'ID_BB_GLOBAL_ULT_PARENT_CO_NAME',
#  'ID_BB_UNIQUE',
#  'ID_CUSIP',
#  'ID_CUSIP_REAL',
#  'ID_EXCH_SYMBOL',
#  'ID_ISIN',
#  'ID_SEDOL1',
#  'IDX_RATIO',
#  'INDUSTRY_GROUP',
#  'INDUSTRY_SECTOR',
#  'INDUSTRY_SUBGROUP',
#  'INFLATION_LINKED_INDICATOR',
#  'INT_ACC',
#  'INVERSE_FUND_INDICATOR',
#  'ISSUER',
#  'ISSUER_BULK',
#  'ISSUER_INDUSTRY',
#  'ISSUERS_STOCK',
#  'IVOL',
#  'IVOL_ASK',
#  'IVOL_MID',
#  'KEY_RATE_DUR_10YR',
#  'KEY_RATE_DUR_15YR',
#  'KEY_RATE_DUR_1YR',
#  'KEY_RATE_DUR_20YR',
#  'KEY_RATE_DUR_25YR',
#  'KEY_RATE_DUR_2YR',
#  'KEY_RATE_DUR_30YR',
#  'KEY_RATE_DUR_3MO',
#  'KEY_RATE_DUR_3YR',
#  'KEY_RATE_DUR_4YR',
#  'KEY_RATE_DUR_5YR',
#  'KEY_RATE_DUR_6MO',
#  'KEY_RATE_DUR_6YR',
#  'KEY_RATE_DUR_7YR',
#  'KEY_RATE_DUR_8YR',
#  'KEY_RATE_DUR_9YR',
#  'LAST_PRICE',
#  'LONG_COMP_NAME',
#  'LOW_52WEEK',
#  'LQA_LIQUIDITY_SCORE',
#  'MARKET_SECTOR_DES',
#  'MARKET_STATUS',
#  'MATURITY',
#  'MIFID_MATURITY_DATE',
#  'MIFID_UNDERLYING_INDEX',
#  'MIN_INCREMENT',
#  'MMKT_7D_YIELD',
#  'MOV_AVG_200D',
#  'MTG_ACC_RT',
#  'MTG_ACC_RT_END_DT',
#  'MTG_ACC_RT_START_DT',
#  'MTG_ARM_SUBTYP',
#  'MTG_DEAL_NAME',
#  'MTG_DEAL_TYP',
#  'MTG_FACTOR',
#  'MTG_FACTOR_DT',
#  'MTG_FACTOR_PAY_DT',
#  'MTG_FACTOR_PRINC_PAY',
#  'MTG_GEN_TICKER',
#  'MTG_INT_DIST',
#  'MTG_IS_AGENCY_BACKED',
#  'MTG_IS_MEGA',
#  'MTG_ORIG_AMT',
#  'MTG_PROPERTY_TYP',
#  'MTG_TRANCHE_TYP_LONG',
#  'MTG_TYP',
#  'MTG_WHLN_NUMBER_LOAN',
#  'MTY_TYP',
#  'MUNI_MSRB_DT',
#  'MUNI_MSRB_PX_AVG_BB',
#  'MUNI_MSRB_VOLUME',
#  'NAME',
#  'NET_INCOME',
#  'NORMALIZED_PAYMENT_RANK',
#  'OAS_SOVEREIGN_CURVE',
#  'OAS_SPREAD_ASK',
#  'OAS_SPREAD_BID',
#  'OAS_SPREAD_MID',
#  'OAS_SWAP_CURVE',
#  'OCC_SYMBOL',
#  'OPT_CONT_SIZE',
#  'OPT_DAYS_EXPIRE',
#  'OPT_EXPIRE_DT',
#  'OPT_FINANCE_RT',
#  'OPT_IMPLIED_VOLATILITY_MID',
#  'OPT_MULTIPLIER',
#  'OPT_OPEN_INT',
#  'OPT_PUT_CALL',
#  'OPT_STRIKE_PX',
#  'OPT_UNDL_PX',
#  'OPT_UNDL_TICKER',
#  'OPTION_EXERCISE_TYPE_REALTIME',
#  'PAR_AMT',
#  'PARENT_COMP_NAME',
#  'PARSEKYABLE_DES',
#  'PARSEKYABLE_DES_SOURCE',
#  'PAY_FLT_RATE_IDX',
#  'PCT_PAR_QUOTED',
#  'PFD_SECURITY_INDICATOR',
#  'PREVIOUS_TRADING_DATE',
#  'PRINCIPAL_FACTOR',
#  'PX_ASK',
#  'PX_BID',
#  'PX_CLOSE_1D',
#  'PX_CLOSE_DT',
#  'PX_DIRTY_MID',
#  'PX_DIRTY_MID_EOD',
#  'PX_DISC_MID',
#  'PX_LAST',
#  'PX_LAST_EOD',
#  'PX_MID',
#  'PX_POS_MULT_FACTOR',
#  'PX_VOLUME_1D',
#  'PX_YEST_CLOSE',
#  'QUOTE_FACTOR',
#  'QUOTE_TYP',
#  'RECEIVE_FLT_RATE_IDX',
#  'REDEMP_VAL',
#  'REFERENCE_INDEX',
#  'REFERENCE_INDEX_TERM',
#  'RISK_MID',
#  'RTG_MOODY_NO_WATCH',
#  'RTG_SP_NO_WATCH',
#  'SECURITY_DES',
#  'SECURITY_NAME',
#  'SECURITY_TYP',
#  'SECURITY_TYP2',
#  'SINKABLE',
#  'SINKING_FUND_FACTOR',
#  'START_ACC_DT',
#  'STATE_CODE',
#  'STRIP_TYPE',
#  'STRUCTURED_NOTE_TYPE',
#  'SW_CDS_BUY_SELL_FLAG',
#  'SW_DEAL_NOTL_AMT',
#  'SW_NET_ACC_INT',
#  'SW_PAY_FREQ',
#  'SW_PRIMARY_REF_OBLIGATION_ISIN',
#  'SW_REC_FREQ',
#  'TICKER',
#  'TICKER_AND_EXCH_CODE',
#  'TOTAL_EQUITY',
#  'TRACE_TIME_OF_TRADE',
#  'TRADE_CRNCY',
#  'TRUST_PREFERRED_INDICATOR',
#  'ULT_PARENT_CNTRY_OF_RISK',
#  'UNDERLYING_CUSIP',
#  'UNDERLYING_ISIN',
#  'UNDERLYING_SECURITY_DES',
#  'UNDL_SPOT_TICKER',
#  'VOLATILITY_10D',
#  'VOLATILITY_120D',
#  'VOLATILITY_30D',
#  'VOLATILITY_60D',
#  'VOLATILITY_90D',
#  'VOLUME_AVG_10D',
#  'VOLUME_AVG_20D',
#  'VOLUME_AVG_30D',
#  'VOLUME_AVG_3M',
#  'VOLUME_AVG_6M',
#  'WORKOUT_PX_BID',
#  'WRT_OUTSTANDING',
#  'WRT_SH_PER',
#  'YAS_BOND_YLD',
#  'YAS_MOD_DUR',
#  'YAS_YLD_SPREAD',
#  'YRS_TO_MTY_ISSUE']

# %%
#create a list of columns that reference fields and data fields have in common
shared_columns = set(reference_columns).intersection(corp_pfd_columns)
shared_column_list = []
for i in shared_columns:
    shared_column_list.append(i)
shared_column_list
# Out:
# ['CRNCY',
#  'ID_ISIN',
#  'FIRST_SETTLE_DT',
#  'INFLATION_LINKED_INDICATOR',
#  'PAR_AMT',
#  'CPN_TYP',
#  'ID_BB_GLOBAL',
#  'COUNTRY',
#  'REDEMP_VAL',
#  'ID_SEDOL1',
#  'NAME',
#  'COLLAT_TYP',
#  'SECURITY_TYP',
#  'ISSUER',
#  'SECURITY_TYP2',
#  'REFERENCE_INDEX',
#  'AMT_OUTSTANDING',
#  'CONTINGENT_CONVERSION',
#  'CV_COMMON_TICKER',
#  'MARKET_SECTOR_DES',
#  'INDUSTRY_GROUP',
#  'LONG_COMP_NAME',
#  'CUR_CPN',
#  'ID_EXCH_SYMBOL',
#  'CPN',
#  'DEFAULTED',
#  'CV_CNVS_RATIO',
#  'PARENT_COMP_NAME',
#  'CNTRY_OF_DOMICILE',
#  'TICKER',
#  'EXCH_CODE',
#  'ID_CUSIP_REAL',
#  'INDUSTRY_SECTOR',
#  'ID_BB_UNIQUE',
#  'ISSUER_INDUSTRY',
#  'CV_COMMON_TICKER_EXCH',
#  'MIN_INCREMENT',
#  'CNTRY_OF_INCORPORATION',
#  'INDUSTRY_SUBGROUP',
#  'SINKABLE',
#  'ISSUER_BULK',
#  'MATURITY',
#  'ID_CUSIP',
#  'TRADE_CRNCY',
#  'SECURITY_DES',
#  'ISSUERS_STOCK',
#  'SINKING_FUND_FACTOR',
#  'MTY_TYP',
#  'CALC_TYP_DES',
#  'PCT_PAR_QUOTED']

# %%
#Use the shared column list to filter corp_pfd_df
corp_pfd_df = corp_pfd_df[shared_column_list]
corp_pfd_df
# Out:
#      CRNCY       ID_ISIN FIRST_SETTLE_DT INFLATION_LINKED_INDICATOR  \
# 0      HKD  HK0000416609        20180502                          N
# 1      ARS  ARCILB560016        20180502                          N
# 2      USD  XS1989092116        20190502                          N
# 3      CAD  CA4590568X88        19841217                          N
# 4      USD  US400489AH37        20150630                          N
# ...    ...           ...             ...                        ...
# 2891   USD  US90346JAC62        20190524                          N
# 2892   USD  USP9634CAC57        20190524                          N
# 2893   CLP                      20190415                          Y
# 2894   CLP                      20190415                          N
# 2895   MXN  MX91GM130022        20190531                          N
#
#                  PAR_AMT    CPN_TYP  ID_BB_GLOBAL COUNTRY REDEMP_VAL  \
# 0      1000000.000000000      FIXED  BBG00KRL8RW6      CI  100.00000
# 1          333.334000000   FLOATING  BBG00KRMSZ63      AR  100.00000
# 2         1000.000000000      FIXED  BBG00NZ74Q67      CI  100.00000
# 3       100000.000000000   VARIABLE  BBG00000F4P6    SNAT  100.00000
# 4         1000.000000000  DEFAULTED  BBG009HTFZR5      MX  100.00000
# ...                  ...        ...           ...     ...        ...
# 2891         1.000000000  DEFAULTED  BBG00P8SNLL9      BZ  100.00000
# 2892         1.000000000  DEFAULTED  BBG00P8SXNZ9      BZ  100.00000
# 2893       500.000000000  DEFAULTED  BBG00P96HDD0      CL  100.00000
# 2894  10000000.000000000      FIXED  BBG00P9C1MJ8      CL  100.00000
# 2895       100.000000000   FLOATING  BBG00PBCD484      MX  100.00000
#
#      ID_SEDOL1  ...              ISSUER_BULK  MATURITY   ID_CUSIP TRADE_CRNCY  \
# 0      BJGV5B5  ...          MTR CORP CI LTD  20210502  AS3629704         HKD
# 1               ...             CILBRAKE SRL  20210502  AS3764410         ARS
# 2      BJK3NS0  ...   REDCO PROPERTIES GROUP  20210502  ZS2774298         USD
# 3               ...  INTL BK RECON & DEVELOP  20831201  4590568X8         CAD
# 4      BYY0995  ...     GRUPO POSADAS SAB CV  20220630  400489AH3         USD
# ...        ...  ...                      ...       ...        ...         ...
# 2891            ...   USJ ACUCAR E ALCOOL SA  20231109  90346JAC6         USD
# 2892   BJYJF77  ...   USJ ACUCAR E ALCOOL SA  20231109  ZS8402340         USD
# 2893            ...  LATAM AIRLINES GROUP SA  20290415  ZS8705577         CLF
# 2894            ...    FACTORING SECURITY SA  20240415  ZS8952088         CLP
# 2895            ...   GM FINANCIAL DE MEXICO  20210528  ZS9312746         MXN
#
#                SECURITY_DES ISSUERS_STOCK SINKING_FUND_FACTOR      MTY_TYP  \
# 0        MTRC 2.56 05/02/21                        1.00000000  AT MATURITY
# 1     CILBAR Float 05/02/21                        1.00000000     SINKABLE
# 2     REDPRO 9 7/8 05/02/21                        1.00000000  AT MATURITY
# 3       IBRD Float 12/01/83                        1.00000000     CALLABLE
# 4     POSADA 7 7/8 06/30/22                        1.00000000     CALLABLE
# ...                     ...           ...                 ...          ...
# 2891  USJACU 9 7/8 11/09/23                        1.00000000    CALL/SINK
# 2892  USJACU 9 7/8 11/09/23                        1.00000000    CALL/SINK
# 2893     LTMCI 3.6 04/15/29                        1.00000000  AT MATURITY
# 2894    SECUCL 4.4 04/15/24                        1.00000000     CALLABLE
# 2895   GMFIN Float 05/28/21                        1.00000000  AT MATURITY
#
#             CALC_TYP_DES PCT_PAR_QUOTED
# 0     HONG KONG GOVT BDS              Y
# 1             ARGENT FLT              Y
# 2      STREET CONVENTION              Y
# 3       NO CALC-FLOATERS              Y
# 4      STREET CONVENTION              Y
# ...                  ...            ...
# 2891  CF BASED CASH SINK              Y
# 2892  CF BASED CASH SINK              Y
# 2893  CHILE COMPOUND INT              Y
# 2894  CHILE COMPOUND INT              Y
# 2895    FLOAT RATE NOTES              N
#
# [2896 rows x 50 columns]

# %% [markdown]
# # 3. Create new_securities.csv

# %%
#Read in reference_securities.csv file
reference_securities_df = pd.read_csv('reference_securities.csv')
reference_securities_df
# Out:
#       id_bb_global       id_isin   id_cusip id_sedol1     ticker  \
# 0     BBG00M6Q1G73  US86562MBE93  86562MBE9       NaN     SUMIBK
# 1     BBG00M6NCQ03  XS1894558102  AU9091243   BGHHDV7     CPIPGR
# 2     BBG001DLF483  US40414LAD10  40414LAD1   B4M5VN0        HCP
# 3     BBG006JN2YG1  US200340AP22  200340AP2   BMW3WN7        CMA
# 4     BBG00K9516J9  US98956PAP71  98956PAP7   BD5GPH5        ZBH
# ...            ...           ...        ...       ...        ...
# 3239  BBG00P8SNLL9  US90346JAC62  90346JAC6            ZS8358328
# 3240  BBG00P8SXNZ9  USP9634CAC57  ZS8402340   BJYJF77  ZS8402340
# 3241  BBG00P96HDD0                ZS8705577            ZS8705577
# 3242  BBG00P9C1MJ8                ZS8952088            ZS8952088
# 3243  BBG00PBCD484  MX91GM130022  ZS9312746            ZS9312746
#
#                           name   exch_code                    issuer  \
# 0     SUMITOMO MITSUI FINL GRP  LUXEMBOURG  SUMITOMO MITSUI FINL GRP
# 1        CPI PROPERTY GROUP SA      DUBLIN     CPI PROPERTY GROUP SA
# 2                      HCP INC    NEW YORK                   HCP INC
# 3                COMERICA INC          NaN              COMERICA INC
# 4     ZIMMER BIOMET HLDGS INC          NaN    ZIMMER BIOMET HOLDINGS
# ...                        ...         ...                       ...
# 3239    USJ ACUCAR E ALCOOL SA       TRACE    USJ ACUCAR E ALCOOL SA
# 3240    USJ ACUCAR E ALCOOL SA       TRACE    USJ ACUCAR E ALCOOL SA
# 3241   LATAM AIRLINES GROUP SA    SANTIAGO   LATAM AIRLINES GROUP SA
# 3242     FACTORING SECURITY SA    SANTIAGO     FACTORING SECURITY SA
# 3243    GM FINANCIAL DE MEXICO  NOT LISTED    GM FINANCIAL DE MEXICO
#
#      market_sector_des
# 0                 Corp
# 1                 Corp
# 2                 Corp
# 3                 Corp
# 4                 Corp
# ...                ...
# 3239              Corp
# 3240              Corp
# 3241              Corp
# 3242              Corp
# 3243              Corp
#
# [3244 rows x 9 columns]

# %%
new_securities = pd.merge(corp_pfd_df, reference_securities_df, how='outer', left_on='ID_BB_GLOBAL', right_on='id_bb_global', indicator = True)

# %%
new_securities
# Out:
#      CRNCY       ID_ISIN FIRST_SETTLE_DT INFLATION_LINKED_INDICATOR  \
# 0      HKD  HK0000416609        20180502                          N
# 1      ARS  ARCILB560016        20180502                          N
# 2      USD  XS1989092116        20190502                          N
# 3      CAD  CA4590568X88        19841217                          N
# 4      USD  US400489AH37        20150630                          N
# ...    ...           ...             ...                        ...
# 3240   NaN           NaN             NaN                        NaN
# 3241   NaN           NaN             NaN                        NaN
# 3242   NaN           NaN             NaN                        NaN
# 3243   NaN           NaN             NaN                        NaN
# 3244   NaN           NaN             NaN                        NaN
#
#                 PAR_AMT    CPN_TYP  ID_BB_GLOBAL COUNTRY REDEMP_VAL ID_SEDOL1  \
# 0     1000000.000000000      FIXED  BBG00KRL8RW6      CI  100.00000   BJGV5B5
# 1         333.334000000   FLOATING  BBG00KRMSZ63      AR  100.00000
# 2        1000.000000000      FIXED  BBG00NZ74Q67      CI  100.00000   BJK3NS0
# 3      100000.000000000   VARIABLE  BBG00000F4P6    SNAT  100.00000
# 4        1000.000000000  DEFAULTED  BBG009HTFZR5      MX  100.00000   BYY0995
# ...                 ...        ...           ...     ...        ...       ...
# 3240                NaN        NaN           NaN     NaN        NaN       NaN
# 3241                NaN        NaN           NaN     NaN        NaN       NaN
# 3242                NaN        NaN           NaN     NaN        NaN       NaN
# 3243                NaN        NaN           NaN     NaN        NaN       NaN
# 3244                NaN        NaN           NaN     NaN        NaN       NaN
#
#       ...  id_bb_global       id_isin   id_cusip id_sedol1     ticker  \
# 0     ...  BBG00KRL8RW6  HK0000416609  AS3629704   BJGV5B5  AS3629704
# 1     ...  BBG00KRMSZ63  ARCILB560016  AS3764410            AS3764410
# 2     ...  BBG00NZ74Q67  XS1989092116  ZS2774298   BJK3NS0  ZS2774298
# 3     ...  BBG00000F4P6  CA4590568X88  4590568X8            4590568X8
# 4     ...  BBG009HTFZR5  US400489AH37  400489AH3   BYY0995  AF1220108
# ...   ...           ...           ...        ...       ...        ...
# 3240  ...  BBG010421D09  US459053YP31  459053YP3            BP1278368
# 3241  ...  BBG010421D27  US459053YQ14  459053YQ1            BP1278376
# 3242  ...  BBG010421DB7  US459053YR96  459053YR9            BP1278400
# 3243  ...  BBG010421DF3  US459053YS79  459053YS7            BP1278426
# 3244  ...  BBG010421DK7  US459053YT52  459053YT5            BP1278442
#
#                          name     exch_code                   issuer  \
# 0             MTR CORP CI LTD    NOT LISTED          MTR CORP CI LTD
# 1                CILBRAKE SRL  BUENOS AIRES             CILBRAKE SRL
# 2      REDCO PROPERTIES GROUP        SGX-ST   REDCO PROPERTIES GROUP
# 3     INTL BK RECON & DEVELOP    NOT LISTED  INTL BK RECON & DEVELOP
# 4        GRUPO POSADAS SAB CV         TRACE     GRUPO POSADAS SAB CV
# ...                       ...           ...                      ...
# 3240       IBRD DISCOUNT NOTE    NOT LISTED       IBRD DISCOUNT NOTE
# 3241       IBRD DISCOUNT NOTE    NOT LISTED       IBRD DISCOUNT NOTE
# 3242       IBRD DISCOUNT NOTE    NOT LISTED       IBRD DISCOUNT NOTE
# 3243       IBRD DISCOUNT NOTE    NOT LISTED       IBRD DISCOUNT NOTE
# 3244       IBRD DISCOUNT NOTE    NOT LISTED       IBRD DISCOUNT NOTE
#
#      market_sector_des      _merge
# 0                 Corp        both
# 1                 Corp        both
# 2                 Corp        both
# 3                 Corp        both
# 4                 Corp        both
# ...                ...         ...
# 3240              Corp  right_only
# 3241              Corp  right_only
# 3242              Corp  right_only
# 3243              Corp  right_only
# 3244              Corp  right_only
#
# [3245 rows x 60 columns]

# %%
#filter new_securities_df to securities in input file that don't exist in reference_securities_df
new_securities_df = new_securities[new_securities['_merge'] == "left_only"]

# %%
new_securities_df
# Out:
#      CRNCY       ID_ISIN FIRST_SETTLE_DT INFLATION_LINKED_INDICATOR  \
# 1446   SEK  SE0001233990        20040709                          Y
#
#                 PAR_AMT CPN_TYP  ID_BB_GLOBAL COUNTRY REDEMP_VAL ID_SEDOL1  \
# 1446  1000000.000000000   FIXED  BBG000064N91    MULT  147.10689   B7NCQ92
#
#       ... id_bb_global id_isin id_cusip id_sedol1 ticker name exch_code  \
# 1446  ...          NaN     NaN      NaN       NaN    NaN  NaN       NaN
#
#      issuer market_sector_des     _merge
# 1446    NaN               NaN  left_only
#
# [1 rows x 60 columns]

# %%
#specify columns to keep (to match reference_securities_df format)
columns_to_keep = ['ID_BB_GLOBAL', 'ID_ISIN', 'ID_CUSIP', 'ID_SEDOL1', 'TICKER', 'NAME', 'EXCH_CODE', 'ISSUER', 'MARKET_SECTOR_DES']

# %%
new_securities_df = new_securities_df[columns_to_keep]

# %%
new_securities_df
# Out:
#       ID_BB_GLOBAL       ID_ISIN   ID_CUSIP ID_SEDOL1  TICKER  \
# 1446  BBG000064N91  SE0001233990  ED5429110   B7NCQ92  OREKON
#
#                     NAME       EXCH_CODE              ISSUER MARKET_SECTOR_DES
# 1446  ORESUNDSKONSORTIET  NOMX STOCKHOLM  ORESUNDSKONSORTIET              Govt

# %%
#Convert all the column names to lowercase 
columns_to_lower = {
    'ID_BB_GLOBAL': 'id_bb_global',
    'ID_ISIN': 'id_isin',
    'ID_CUSIP': 'id_cusip',
    'ID_SEDOL1': 'id_sedol1',
    'TICKER': 'ticker',
    'NAME': 'name',
    'EXCH_CODE': 'exch_code',
    'ISSUER': 'issuer',
    'MARKET_SECTOR_DES': 'market_sector_des'
}

new_securities_df.rename(columns=columns_to_lower, inplace=True)
new_securities_df
# Out:
# /var/folders/bl/y0rxwzrs5ynfzgl_ld5fd8jc0000gn/T/ipykernel_53258/827632550.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_securities_df.rename(columns=columns_to_lower, inplace=True)
#       id_bb_global       id_isin   id_cusip id_sedol1  ticker  \
# 1446  BBG000064N91  SE0001233990  ED5429110   B7NCQ92  OREKON
#
#                     name       exch_code              issuer market_sector_des
# 1446  ORESUNDSKONSORTIET  NOMX STOCKHOLM  ORESUNDSKONSORTIET              Govt

# %%
#Convert new_securities_df to a csv
new_securities_df.to_csv('new_securities.csv', index=False)

# %% [markdown]
# # 4. Create security_data.csv

# %%
#merge new_securities_df and reference_securities_df to cover whole population
merged_df = pd.concat([new_securities_df, reference_securities_df], ignore_index=True)
merged_df
# Out:
#       id_bb_global       id_isin   id_cusip id_sedol1     ticker  \
# 0     BBG000064N91  SE0001233990  ED5429110   B7NCQ92     OREKON
# 1     BBG00M6Q1G73  US86562MBE93  86562MBE9       NaN     SUMIBK
# 2     BBG00M6NCQ03  XS1894558102  AU9091243   BGHHDV7     CPIPGR
# 3     BBG001DLF483  US40414LAD10  40414LAD1   B4M5VN0        HCP
# 4     BBG006JN2YG1  US200340AP22  200340AP2   BMW3WN7        CMA
# ...            ...           ...        ...       ...        ...
# 3240  BBG00P8SNLL9  US90346JAC62  90346JAC6            ZS8358328
# 3241  BBG00P8SXNZ9  USP9634CAC57  ZS8402340   BJYJF77  ZS8402340
# 3242  BBG00P96HDD0                ZS8705577            ZS8705577
# 3243  BBG00P9C1MJ8                ZS8952088            ZS8952088
# 3244  BBG00PBCD484  MX91GM130022  ZS9312746            ZS9312746
#
#                           name       exch_code                    issuer  \
# 0           ORESUNDSKONSORTIET  NOMX STOCKHOLM        ORESUNDSKONSORTIET
# 1     SUMITOMO MITSUI FINL GRP      LUXEMBOURG  SUMITOMO MITSUI FINL GRP
# 2        CPI PROPERTY GROUP SA          DUBLIN     CPI PROPERTY GROUP SA
# 3                      HCP INC        NEW YORK                   HCP INC
# 4                COMERICA INC              NaN              COMERICA INC
# ...                        ...             ...                       ...
# 3240    USJ ACUCAR E ALCOOL SA           TRACE    USJ ACUCAR E ALCOOL SA
# 3241    USJ ACUCAR E ALCOOL SA           TRACE    USJ ACUCAR E ALCOOL SA
# 3242   LATAM AIRLINES GROUP SA        SANTIAGO   LATAM AIRLINES GROUP SA
# 3243     FACTORING SECURITY SA        SANTIAGO     FACTORING SECURITY SA
# 3244    GM FINANCIAL DE MEXICO      NOT LISTED    GM FINANCIAL DE MEXICO
#
#      market_sector_des
# 0                 Govt
# 1                 Corp
# 2                 Corp
# 3                 Corp
# 4                 Corp
# ...                ...
# 3240              Corp
# 3241              Corp
# 3242              Corp
# 3243              Corp
# 3244              Corp
#
# [3245 rows x 9 columns]

# %%
rows = []
for index, row in merged_df.iterrows():
    id_bb_global = row['id_bb_global']
    for column in new_securities_df.columns:
        if column != 'id_bb_global': 
            field_name = column
            field_value = row[column]
            source = 'corp_pfd.diff'
            timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
            rows.append({'ID_BB_GLOBAL': id_bb_global,
                         'FIELD': field_name,
                         'VALUE': field_value,
                         'SOURCE': source,
                         'TSTAMP': timestamp})

# %%
# Create a DataFrame from the list of rows
security_data_df = pd.DataFrame(rows)

# %%
security_data_df
# Out:
#        ID_BB_GLOBAL              FIELD                   VALUE         SOURCE  \
# 0      BBG000064N91            id_isin            SE0001233990  corp_pfd.diff
# 1      BBG000064N91           id_cusip               ED5429110  corp_pfd.diff
# 2      BBG000064N91          id_sedol1                 B7NCQ92  corp_pfd.diff
# 3      BBG000064N91             ticker                  OREKON  corp_pfd.diff
# 4      BBG000064N91               name      ORESUNDSKONSORTIET  corp_pfd.diff
# ...             ...                ...                     ...            ...
# 25955  BBG00PBCD484             ticker               ZS9312746  corp_pfd.diff
# 25956  BBG00PBCD484               name  GM FINANCIAL DE MEXICO  corp_pfd.diff
# 25957  BBG00PBCD484          exch_code              NOT LISTED  corp_pfd.diff
# 25958  BBG00PBCD484             issuer  GM FINANCIAL DE MEXICO  corp_pfd.diff
# 25959  BBG00PBCD484  market_sector_des                    Corp  corp_pfd.diff
#
#                     TSTAMP
# 0      2024-02-23 21:56:28
# 1      2024-02-23 21:56:28
# 2      2024-02-23 21:56:28
# 3      2024-02-23 21:56:28
# 4      2024-02-23 21:56:28
# ...                    ...
# 25955  2024-02-23 21:56:28
# 25956  2024-02-23 21:56:28
# 25957  2024-02-23 21:56:28
# 25958  2024-02-23 21:56:28
# 25959  2024-02-23 21:56:28
#
# [25960 rows x 5 columns]

# %%
# Save the DataFrame to a CSV file
security_data_df.to_csv('security_data.csv', index=False)
